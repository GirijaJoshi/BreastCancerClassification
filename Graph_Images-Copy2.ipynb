# %%
import os
from pprint import pprint
from tqdm import tqdm
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
# Out:
# C:\Users\Girija Joshi\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Girija Joshi\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Girija Joshi\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# create a Resources/temp/original in current directory
files = os.listdir("Resources/IDC_regular_ps50_idx5")
print('Patient IDs')
files
# Out:
# Patient IDs
# ['10254',
#  '10255',
#  '10256',
#  '10257',
#  '10258',
#  '10259',
#  '10260',
#  '10261',
#  '10262',
#  '10264',
#  '10268',
#  '10269',
#  '10272',
#  '10273',
#  '10274',
#  '10275',
#  '10276',
#  '10277',
#  '10278',
#  '10279',
#  '10282',
#  '10285',
#  '10286',
#  '10288',
#  '10290',
#  '10291',
#  '10292',
#  '10293',
#  '10295',
#  '10299',
#  '10300',
#  '10301',
#  '10302',
#  '10303',
#  '10304',
#  '10305',
#  '10306',
#  '10307',
#  '10308',
#  '12241',
#  '12242',
#  '12626',
#  '12748',
#  '12749',
#  '12750',
#  '12751',
#  '12752',
#  '12810',
#  '12811',
#  '12817',
#  '12818',
#  '12819',
#  '12820',
#  '12821',
#  '12822',
#  '12823',
#  '12824',
#  '12826',
#  '12867',
#  '12868',
#  '12869',
#  '12870',
#  '12871',
#  '12872',
#  '12873',
#  '12875',
#  '12876',
#  '12877',
#  '12878',
#  '12879',
#  '12880',
#  '12881',
#  '12882',
#  '12883',
#  '12884',
#  '12886',
#  '12890',
#  '12891',
#  '12892',
#  '12893',
#  '12894',
#  '12895',
# ...

# %%
base_path = 'Resources/IDC_regular_ps50_idx5/'
patient_ids = os.listdir(base_path)
patient_ids
# Out:
# ['10254',
#  '10255',
#  '10256',
#  '10257',
#  '10258',
#  '10259',
#  '10260',
#  '10261',
#  '10262',
#  '10264',
#  '10268',
#  '10269',
#  '10272',
#  '10273',
#  '10274',
#  '10275',
#  '10276',
#  '10277',
#  '10278',
#  '10279',
#  '10282',
#  '10285',
#  '10286',
#  '10288',
#  '10290',
#  '10291',
#  '10292',
#  '10293',
#  '10295',
#  '10299',
#  '10300',
#  '10301',
#  '10302',
#  '10303',
#  '10304',
#  '10305',
#  '10306',
#  '10307',
#  '10308',
#  '12241',
#  '12242',
#  '12626',
#  '12748',
#  '12749',
#  '12750',
#  '12751',
#  '12752',
#  '12810',
#  '12811',
#  '12817',
#  '12818',
#  '12819',
#  '12820',
#  '12821',
#  '12822',
#  '12823',
#  '12824',
#  '12826',
#  '12867',
#  '12868',
#  '12869',
#  '12870',
#  '12871',
#  '12872',
#  '12873',
#  '12875',
#  '12876',
#  '12877',
#  '12878',
#  '12879',
#  '12880',
#  '12881',
#  '12882',
#  '12883',
#  '12884',
#  '12886',
#  '12890',
#  '12891',
#  '12892',
#  '12893',
#  '12894',
#  '12895',
#  '12896',
# ...

# %%
class_0_total = 0
class_1_total = 0

# %%
now = datetime.now()
start_filename = now.strftime("%H:%M:%S.%f")
print(f'Start Reading All File Names: {start_filename}')
# Out:
# Start Reading All File Names: 20:55:39.471313

# %%
# reading all file names with all the folders and sub folders
for patient_id in patient_ids:
    class_0_files = os.listdir(base_path + patient_id + '/0')
    class_1_files = os.listdir(base_path + patient_id + '/1')

    class_0_total += len(class_0_files)
    class_1_total += len(class_1_files) 

total_images = class_0_total + class_1_total
    
print(f'Number of patches in Class 0: {class_0_total}')
print(f'Number of patches in Class 1: {class_1_total}')
print(f'Total number of patches: {total_images}')

now = datetime.now()
end_filename = now.strftime("%H:%M:%S.%f")
print(f'End Reading All File Names: {end_filename}')
# Out:
# Number of patches in Class 0: 198259
# Number of patches in Class 1: 78716
# Total number of patches: 276975
# End Reading All File Names: 20:55:53.210656

# %%
columns = ["patient_id",'x_cordinate','y_cordinate',"target","path"]
data_rows = []
i = 0
iss = 0
isss = 0

# %%
# getting path name of all the images
for patient_id in tqdm(patient_ids):
    for c in [0,1]:
        
        class_path = base_path + patient_id + '/' + str(c) + '/'
        print(class_path)
        imgs = os.listdir(class_path)
        # print(f'Images:{imgs}')
        # input('----------------------')
        
        # Extracting Image Paths
        img_paths = [class_path + img + '/' for img in imgs]
        # print(f'Image Path: {img_paths} ')

        img_coords = [img.split('_',4)[2:4] for img in imgs]
        x_coords = [int(coords[0][1:]) for coords in img_coords]
        y_coords = [int(coords[1][1:]) for coords in img_coords]

        for (path,x,y) in zip(img_paths,x_coords,y_coords):
            values = [patient_id,x,y,c,path]
            data_rows.append({k:v for (k,v) in zip(columns,values)})
# Out:
#   3%|██▋                                                                               | 9/278 [00:00<00:03, 88.66it/s]
# Resources/IDC_regular_ps50_idx5/10254/0/
# Resources/IDC_regular_ps50_idx5/10254/1/
# Resources/IDC_regular_ps50_idx5/10255/0/
# Resources/IDC_regular_ps50_idx5/10255/1/
# Resources/IDC_regular_ps50_idx5/10256/0/
# Resources/IDC_regular_ps50_idx5/10256/1/
# Resources/IDC_regular_ps50_idx5/10257/0/
# Resources/IDC_regular_ps50_idx5/10257/1/
# Resources/IDC_regular_ps50_idx5/10258/0/
# Resources/IDC_regular_ps50_idx5/10258/1/
# Resources/IDC_regular_ps50_idx5/10259/0/
# Resources/IDC_regular_ps50_idx5/10259/1/
# Resources/IDC_regular_ps50_idx5/10260/0/
# Resources/IDC_regular_ps50_idx5/10260/1/
# Resources/IDC_regular_ps50_idx5/10261/0/
# Resources/IDC_regular_ps50_idx5/10261/1/
# Resources/IDC_regular_ps50_idx5/10262/0/
# Resources/IDC_regular_ps50_idx5/10262/1/
# Resources/IDC_regular_ps50_idx5/10264/0/
# Resources/IDC_regular_ps50_idx5/10264/1/
# ...

# %%
data = pd.DataFrame(data_rows)
data
# Out:
#        patient_id  x_cordinate  y_cordinate  target  \
# 0           10254         1001         1001       0
# 1           10254         1001         1051       0
# 2           10254         1001         1201       0
# 3           10254         1001         1251       0
# 4           10254         1001         1301       0
# ...           ...          ...          ...     ...
# 276970       9383         2051          901       1
# 276971       9383         2051          951       1
# 276972       9383         2101         1001       1
# 276973       9383         2101          901       1
# 276974       9383         2101          951       1
#
#                                                      path
# 0       Resources/IDC_regular_ps50_idx5/10254/0/10254_...
# 1       Resources/IDC_regular_ps50_idx5/10254/0/10254_...
# 2       Resources/IDC_regular_ps50_idx5/10254/0/10254_...
# 3       Resources/IDC_regular_ps50_idx5/10254/0/10254_...
# ...

# %%
data.shape
# Out:
# (276975, 5)

# %%
def get_classes_split(series):
    ratio = np.round(series.value_counts()/series.count()*100,decimals = 1)
    return ratio

# %%
import random
# shuffling the data
def suffle_patient_ids(data_frame):
    patient_groups = [df for _, df in data_frame.groupby('patient_id')]
    random.shuffle(patient_groups)
    shuffled_df = pd.concat(patient_groups).reset_index(drop=True)
    return shuffled_df

# %%
from sklearn.model_selection import train_test_split
for i in range(3):
    data = suffle_patient_ids(data)
    display(data.head())
# Out:
#   patient_id  x_cordinate  y_cordinate  target  \
# 0       8984         1001         1001       0
# 1       8984         1001         1051       0
# 2       8984         1001         1101       0
# 3       8984         1001         1151       0
# 4       8984         1001         1201       0
#
#                                                 path
# 0  Resources/IDC_regular_ps50_idx5/8984/0/8984_id...
# 1  Resources/IDC_regular_ps50_idx5/8984/0/8984_id...
# 2  Resources/IDC_regular_ps50_idx5/8984/0/8984_id...
# 3  Resources/IDC_regular_ps50_idx5/8984/0/8984_id...
# 4  Resources/IDC_regular_ps50_idx5/8984/0/8984_id...
#   patient_id  x_cordinate  y_cordinate  target  \
# 0      10276         1001         1301       0
# 1      10276         1001         1351       0
# 2      10276         1001         1401       0
# 3      10276         1001         1451       0
# 4      10276         1001         1501       0
#
#                                                 path
# ...

# %%
get_classes_split(data['target'])
# Out:
# 0    71.6
# 1    28.4
# Name: target, dtype: float64

# %%
# Create test and train data
X = data.loc[:,data.columns != 'target']
print(X.columns)
# Out:
# Index(['patient_id', 'x_cordinate', 'y_cordinate', 'path'], dtype='object')

# %%
# retrieve the target column and store them in y 
y = data.loc[:,['target']]

# %%
def split_data(data,train_test_percentage = 0.7,percentage_of_dataset = 0.2):
    # get number of datapoints to split from the total dataset
    n_points = round(data.shape[0]*0.2)
    # retrieve the desired initial split of the data based on the specified percentage of the dataset
    data = data[0:n_points]
    # retrieve all the columns except the target columns and store them in X
    X = data.loc[:,data.columns != 'target']
    # retrieve the target column and store them in y 
    y = data.loc[:,['target']]
    # Split the model to training and testing sets for both the features and the targets
    X_train, X_test, y_train, y_test =  train_test_split(X, y, train_size=train_test_percentage, shuffle = False)
    return [X_train, X_test, y_train, y_test]

# %%
# train_test_percentage = 0.7
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_test_percentage, shuffle = False)
X_train, X_test, y_train, y_test = split_data(data)

# %%
print(f'Number of training samples: {X_train.shape[0]} ')
print(f'Number of testing samples: {X_test.shape[0]} ')
# Out:
# Number of training samples: 38776
# Number of testing samples: 16619

# %%
print('training data split:')
display(get_classes_split(y_train['target']))
print('testing data split:')
display(get_classes_split(y_test['target']))
# Out:
# training data split:
# 0    73.7
# 1    26.3
# Name: target, dtype: float64
# testing data split:
# 0    77.7
# 1    22.3
# Name: target, dtype: float64

# %%
X_train.head()
# Out:
#   patient_id  x_cordinate  y_cordinate  \
# 0      12954         1001         1001
# 1      12954         1001         1051
# 2      12954         1001         1101
# 3      12954         1001         1151
# 4      12954         1001         1201
#
#                                                 path
# 0  Resources/IDC_regular_ps50_idx5/12954/0/12954_...
# 1  Resources/IDC_regular_ps50_idx5/12954/0/12954_...
# 2  Resources/IDC_regular_ps50_idx5/12954/0/12954_...
# 3  Resources/IDC_regular_ps50_idx5/12954/0/12954_...
# 4  Resources/IDC_regular_ps50_idx5/12954/0/12954_...

# %%
X_train.shape
# Out:
# (38776, 4)

# %%
X_test.head()
# Out:
#       patient_id  x_cordinate  y_cordinate  \
# 38776      13617         1701          251
# 38777      13617         1701          301
# 38778      13617         1701          351
# 38779      13617         1751          101
# 38780      13617         1751          151
#
#                                                     path
# 38776  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38777  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38778  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38779  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38780  Resources/IDC_regular_ps50_idx5/13617/0/13617_...

# %%
X_test.shape
# Out:
# (16619, 4)

# %%
X_test.head()
# Out:
#       patient_id  x_cordinate  y_cordinate  \
# 38776      13617         1701          251
# 38777      13617         1701          301
# 38778      13617         1701          351
# 38779      13617         1751          101
# 38780      13617         1751          151
#
#                                                     path
# 38776  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38777  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38778  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38779  Resources/IDC_regular_ps50_idx5/13617/0/13617_...
# 38780  Resources/IDC_regular_ps50_idx5/13617/0/13617_...

# %%
# path to images
img_path = X_train.path[0]
img_path
# Out:
# 'Resources/IDC_regular_ps50_idx5/12954/0/12954_idx5_x1001_y1001_class0.png/'

# %%
# reduce the image dimentions to (50,50,3)
# path to images
img_path = X_train.path[0]
# reading the images
rgb_img = io.imread(img_path)
gray_img = io.imread(img_path, as_gray = True)
print(f'rgb image dimension: {rgb_img.shape}')
print(f'grayscale image dimension: {gray_img.shape}')
# Out:
# rgb image dimension: (50, 50, 3)
# grayscale image dimension: (50, 50)

# %%
# apply this reduced dimentions to X_train and then flatten it and store it in array
def paths_to_array(paths,n_pixels = 2500):
    imgs_array = np.zeros((paths.shape[0],n_pixels))
    for i,path in tqdm(enumerate(paths),total = imgs_array.shape[0]):
        # Read image
        img = io.imread(path,as_gray = True)
        # Flatten image
        img = img.flatten()
        # Store image in corresponding array row
        imgs_array[i,0:img.shape[0]] = img
    return imgs_array

# %%
# Store paths inside variable
paths = X_train.path
# Convert paths to array of images
imgs_array = paths_to_array(paths)
imgs_array.shape
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 38776/38776 [02:29<00:00, 259.94it/s]
# (38776, 2500)

# %%
# get average pixel values of each flatterned image 
imgs_array_mean = imgs_array.mean(axis = 1)
X_train['img_mean'] = imgs_array_mean

# %%
X_train.head()
# Out:
#   patient_id  x_cordinate  y_cordinate  \
# 0      12954         1001         1001
# 1      12954         1001         1051
# 2      12954         1001         1101
# 3      12954         1001         1151
# 4      12954         1001         1201
#
#                                                 path  img_mean
# 0  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.724766
# 1  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.697959
# 2  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.687887
# 3  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.691522
# 4  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.692674

# %%
# we need more features, we can do that by getting average pixel valyes for each quaderent
def avg_quadrants(flat_img):
    # get the shape of the image array 
    shape = np.sqrt(flat_img.shape[0]).astype(int)
    shape_2 = (shape/2).astype(int)
    # reshape the flat image in order to extract the quadrants
    img = flat_img.reshape(shape,shape)
    # get the mean value for each quadrant
    top_left = img[:shape_2,:shape_2].mean()
    top_right = img[:shape_2,shape_2:].mean()
    bottom_right = img[shape_2:,shape_2:].mean()
    bottom_left = img[shape_2:,:shape_2].mean()
    
    return [top_left,top_right,bottom_left,bottom_right]

# %%
# find out the average of all the images
def get_quadrant_array(imgs_array):
    # initialize array of zeros
    avg_quad_array = np.zeros((imgs_array.shape[0],4))
    # loop through imgs_array and get the averages for each quadrant
    for i in tqdm(range(imgs_array.shape[0])):
        flat_img = imgs_array[i]
        quad_avgs = avg_quadrants(flat_img)
        avg_quad_array[i] = quad_avgs
    return avg_quad_array

# %%
avgs_array = get_quadrant_array(imgs_array)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 38776/38776 [00:02<00:00, 13214.71it/s]

# %%
# create a new pandas dataframe using the numpy average quadrant image data
avg_quad_df = pd.DataFrame(avgs_array, columns = ['top_left','top_right','bottom_left','bottom_right'])
avg_quad_df.head()
# Out:
#    top_left  top_right  bottom_left  bottom_right
# 0  0.758376   0.713609     0.741910      0.685167
# 1  0.751413   0.696430     0.649380      0.694615
# 2  0.646234   0.661483     0.713351      0.730481
# 3  0.717043   0.708653     0.667720      0.672674
# 4  0.675300   0.670728     0.704108      0.720560

# %%
# merge 2 data frames
X_train = pd.concat((X_train,avg_quad_df), axis = 1) 
X_train.head()
# Out:
#   patient_id  x_cordinate  y_cordinate  \
# 0      12954         1001         1001
# 1      12954         1001         1051
# 2      12954         1001         1101
# 3      12954         1001         1151
# 4      12954         1001         1201
#
#                                                 path  img_mean  top_left  \
# 0  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.724766  0.758376
# 1  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.697959  0.751413
# 2  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.687887  0.646234
# 3  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.691522  0.717043
# 4  Resources/IDC_regular_ps50_idx5/12954/0/12954_...  0.692674  0.675300
#
#    top_right  bottom_left  bottom_right
# 0   0.713609     0.741910      0.685167
# 1   0.696430     0.649380      0.694615
# 2   0.661483     0.713351      0.730481
# 3   0.708653     0.667720      0.672674
# 4   0.670728     0.704108      0.720560

# %%
# Start Trainling the model
# as path is not integer so we are not considering that
X_train = X_train.loc[:,['img_mean','top_left','top_right','bottom_left','bottom_right']]
X_train.head()
# Out:
#    img_mean  top_left  top_right  bottom_left  bottom_right
# 0  0.724766  0.758376   0.713609     0.741910      0.685167
# 1  0.697959  0.751413   0.696430     0.649380      0.694615
# 2  0.687887  0.646234   0.661483     0.713351      0.730481
# 3  0.691522  0.717043   0.708653     0.667720      0.672674
# 4  0.692674  0.675300   0.670728     0.704108      0.720560

# %%
# do gray scale and flateening for X_test too
# reduce the image dimentions to (50,50,3)
# path to images
# img_path_test = X_test.path[0]
img_path_test = X_test['path'].iloc[0]
print(img_path_test)

# reading the images
rgb_img_test = io.imread(img_path_test)
gray_img_test = io.imread(img_path_test, as_gray = True)
print(f'rgb image dimension: {rgb_img_test.shape}')
print(f'grayscale image dimension: {gray_img_test.shape}')
# Out:
# Resources/IDC_regular_ps50_idx5/13617/0/13617_idx5_x1701_y251_class0.png/
# rgb image dimension: (50, 50, 3)
# grayscale image dimension: (50, 50)

# %%
# Store paths inside variable
paths_test = X_test.path
# Convert paths to array of images
imgs_array_test = paths_to_array(paths_test)
imgs_array_test.shape
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 16619/16619 [00:48<00:00, 341.89it/s]
# (16619, 2500)

# %%
# get average pixel values of each flatterned image 
imgs_array_mean_test = imgs_array_test.mean()
X_test['img_mean'] = imgs_array_mean_test

# %%
X_test['img_mean']
# Out:
# 38776    0.692026
# 38777    0.692026
# 38778    0.692026
# 38779    0.692026
# 38780    0.692026
#            ...
# 55390    0.692026
# 55391    0.692026
# 55392    0.692026
# 55393    0.692026
# 55394    0.692026
# Name: img_mean, Length: 16619, dtype: float64

# %%
X_test.columns
# Out:
# Index(['patient_id', 'x_cordinate', 'y_cordinate', 'path', 'img_mean'], dtype='object')

# %%
imgs_array_mean_test
# Out:
# 0.6920259893943184

# %%
avgs_array_test = get_quadrant_array(imgs_array_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 16619/16619 [00:01<00:00, 9871.26it/s]

# %%
avgs_array_test
# Out:
# array([[0.76954592, 0.82695132, 0.89410288, 0.91042865],
#        [0.64447563, 0.66920722, 0.84111409, 0.74365308],
#        [0.86286104, 0.73349363, 0.98250568, 0.88186528],
#        ...,
#        [0.61178532, 0.59197072, 0.51136357, 0.53580462],
#        [0.48235257, 0.47078264, 0.60898718, 0.61066097],
#        [0.52903103, 0.56976092, 0.49633764, 0.49702038]])

# %%
# create a new pandas dataframe using the numpy average quadrant image data
avg_quad_test_df = pd.DataFrame(avgs_array_test, columns = ['top_left','top_right','bottom_left','bottom_right'], index=X_test.index)
# avg_quad_test_df= avg_quad_test_df.reset_index()
avg_quad_test_df.head()
# Out:
#        top_left  top_right  bottom_left  bottom_right
# 38776  0.769546   0.826951     0.894103      0.910429
# 38777  0.644476   0.669207     0.841114      0.743653
# 38778  0.862861   0.733494     0.982506      0.881865
# 38779  0.927626   0.942208     0.742555      0.681989
# 38780  0.654193   0.629897     0.594707      0.631911

# %%
X_test.head()
# Out:
#       patient_id  x_cordinate  y_cordinate  \
# 38776      13617         1701          251
# 38777      13617         1701          301
# 38778      13617         1701          351
# 38779      13617         1751          101
# 38780      13617         1751          151
#
#                                                     path  img_mean
# 38776  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026
# 38777  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026
# 38778  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026
# 38779  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026
# 38780  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026

# %%
# X_test = X_test.merge(avg_quad_test_df,left_index=True, right_index=True)
X_test = pd.concat((X_test,avg_quad_test_df), axis = 1) 
X_test.head()
# Out:
#       patient_id  x_cordinate  y_cordinate  \
# 38776      13617         1701          251
# 38777      13617         1701          301
# 38778      13617         1701          351
# 38779      13617         1751          101
# 38780      13617         1751          151
#
#                                                     path  img_mean  top_left  \
# 38776  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026  0.769546
# 38777  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026  0.644476
# 38778  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026  0.862861
# 38779  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026  0.927626
# 38780  Resources/IDC_regular_ps50_idx5/13617/0/13617_...  0.692026  0.654193
#
#        top_right  bottom_left  bottom_right
# 38776   0.826951     0.894103      0.910429
# 38777   0.669207     0.841114      0.743653
# 38778   0.733494     0.982506      0.881865
# 38779   0.942208     0.742555      0.681989
# ...

# %%
X_test.shape
# Out:
# (16619, 9)

# %%
# Start Trainling the model
# as path is not integer so we are not considering that
# X_test = X_test.loc[:,['img_mean','top_left','top_right','bottom_left','bottom_right']]
X_test = X_test[['img_mean','top_left','top_right','bottom_left','bottom_right']]
X_test.head()
# Out:
#        img_mean  top_left  top_right  bottom_left  bottom_right
# 38776  0.692026  0.769546   0.826951     0.894103      0.910429
# 38777  0.692026  0.644476   0.669207     0.841114      0.743653
# 38778  0.692026  0.862861   0.733494     0.982506      0.881865
# 38779  0.692026  0.927626   0.942208     0.742555      0.681989
# 38780  0.692026  0.654193   0.629897     0.594707      0.631911

# %%
X_train.shape
# Out:
# (38776, 5)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# %%
number_input_features = 5
hidden_nodes_layer1 = 15
hidden_nodes_layer2 = 10
no_epochs = 25

# %%
tf.keras.backend.clear_session()
nn = tf.keras.models.Sequential()
# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu')
)

# Second Layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu')
)

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the tructure of model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 15)                90
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# ...
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# train the model by fit
fit_model = nn.fit(X_train, y_train, epochs=no_epochs)

# Evaluate the model using the test data
# model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
# Out:
# Epoch 1/25
# 38776/38776 [==============================] - 3s 82us/sample - loss: 0.5250 - accuracy: 0.7404
# Epoch 2/25
# 38776/38776 [==============================] - 3s 71us/sample - loss: 0.4903 - accuracy: 0.7616
# Epoch 3/25
# 38776/38776 [==============================] - 3s 71us/sample - loss: 0.4877 - accuracy: 0.7634
# Epoch 4/25
# 38776/38776 [==============================] - 3s 72us/sample - loss: 0.4870 - accuracy: 0.7639
# Epoch 5/25
# 38776/38776 [==============================] - 3s 71us/sample - loss: 0.4867 - accuracy: 0.7626
# Epoch 6/25
# 38776/38776 [==============================] - 3s 72us/sample - loss: 0.4863 - accuracy: 0.7643
# Epoch 7/25
# 38776/38776 [==============================] - 3s 71us/sample - loss: 0.4856 - accuracy: 0.7643
# Epoch 8/25
# 38776/38776 [==============================] - 3s 71us/sample - loss: 0.4860 - accuracy: 0.7644
# Epoch 9/25
# 38776/38776 [==============================] - 3s 64us/sample - loss: 0.4857 - accuracy: 0.7632
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f'Model Loss:{model_loss}, Model Accuracy:{model_accuracy}')
# Out:
# 16619/16619 - 1s - loss: 0.4432 - accuracy: 0.7963
# Model Loss:0.4431817644489852, Model Accuracy:0.796317458152771
